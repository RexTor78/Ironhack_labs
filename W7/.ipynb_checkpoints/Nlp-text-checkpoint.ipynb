# %%
import nltk
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "44.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "44.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "44.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "44.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "44.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "44.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "43.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "43.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "43.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "42.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "42.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "42.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "42.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "41.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "41.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "40.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "40.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "40.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "39.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "39.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "38.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "37.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "37.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "37.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "36.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "36.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "36.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "35.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "35.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "35.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "35.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "35.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "35.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "10.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "9.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "9.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "9.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "8.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "8.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "7.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "7.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "7.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "6.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "6.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "5.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "5.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "4.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "4.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "44.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "44.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "44.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "44.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "44.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "43.0"
# Exception in Tkinter callback
# ...
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "43.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "43.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "43.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "43.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "43.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "43.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "43.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "43.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "43.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "43.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "43.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "43.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "43.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "43.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "42.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "42.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "42.0"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\site-packages\nltk\draw\table.py", line 198, in _resize_column_motion_cb
#     lb["width"] = max(3, lb["width"] + (x1 - x2) // charwidth)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1657, in __setitem__
#     self.configure({key: value})
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1646, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\ProgramData\Anaconda3\envs\Ironhack_env\lib\tkinter\__init__.py", line 1636, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: expected integer but got "42.0"
# True

# %%
import docx2txt

# %%
from nltk.tokenize import word_tokenize
from nltk.text import Text

# %%
textfile=docx2txt.process('luz.docx')

# %%
textfile
# Out:
# 'La luz se encarece un 35% en la primera quincena de julio y la OCU denuncia que la factura oculta el precio de la energía\n\nAsí con las tarifas de los quince primeros días de este mes, el usuario medio pagará 21,68 euros más que en julio de 2020, cuando la factura se situó en 62,67 euros.\n\nNOTICIA\n\nACTUALIZADA 16/7/2021 A LAS 12:00\n\nHERALDO.ES\n\n\n\n\n\n\n\nTeresa Ribera asegura que el precio de la luz seguirá en su línea durante más meses\n\nLa\xa0factura de la luz\xa0de un usuario medio se ha encarecido un 34,6% en la primera quincena de julio con respecto al mismo mes del año pasado, según datos de\xa0Facua-Consumidores en Acción.\n\nADVERTISING\n\nSegún estimaciones de la asociación de consumidores sobre la evolución de la tarifa\xa0semirregulada (PVPC), de seguir así las tarifas, la factura mensual se situaría en 84,35 euros, un importe del recibo aún más elevado que el de junio, cuando fue de 81,27 euros.\n\nAsí, con las tarifas de los quince primeros días de este mes, el usuario medio pagará 21,68 euros más que en julio de 2020, cuando la factura se situó en 62,67 euros.\n\nLa\xa0asociación estima que la bajada del IVA al 10% hasta diciembre mientras el precio medio del megavatio hora\xa0esté por encima de los 45 euros ha amortiguado la subida en 8,44 euros. Si se siguiera aplicando el 21%, el recibo habría batido todos los récords, alcanzado los 92,79 euros.\n\nMÁS INFORMACIÓN\n\n\n\nLavadora, lavavajillas o aire acondicionado: cuánto podemos ahorrar con la bajada del IVA de la luz en la factura\n\n\n\n¿A qué hora será más barato poner la lavadora o el lavavajillas con la nueva factura de la luz?\n\nDe seguir así las tarifas, el de julio será el tercer recibo más caro a nivel histórico para el usuario medio. Hasta la fecha, las cinco facturas más elevadas han sido los 88,66 euros del primer trimestre de 2012, los 87,81 euros de enero de 2017, los 83,55 euros de septiembre de 2018, los 82,13 euros de mayo de 2021 y los 81,55 euros de febrero de 2021.\n\nEl usuario medio utilizado por Facua en sus análisis tiene una potencia contratada de 4,4 kilovatios (kW) -la misma en horario punta y valle- y un consumo de 366 kilovatios hora (kWh) mensuales.\n\nADVERTISING\n\nEn cuanto a los porcentajes de consumo en los tres tramos horarios del nuevo sistema de facturación, la asociación toma como referencia el perfil de usuario medio tradicional sin discriminación horaria publicado por la Comisión Nacional de los Mercados y la Competencia (CNMC), que consume el 45% de la electricidad en el horario valle, el 29% en el horario punta y el 26% en el horario llano. SUBIDA DEL KWH.\n\nEn lo que va julio, el precio del kWh se situó en una media de 11,88 céntimos. En los primeros 15 días de julio, el precio medio ha sido de 13,43 céntimos en horario valle, 17,76 céntimos en horario llano y 28,86 céntimos en horario punta. La media aritmética entre los tres tramos ha sido de 20,02 céntimos, un 68,5% más que hace un año.\n\nFacua ha convocado este jueves concentraciones contra el tarifazo eléctrico en 45 capitales y la ciudad autónoma de Melilla. La asociación plantea un decálogo de reivindicaciones al Gobierno, entre ellas un cambio en las reglas de la subasta del mercado mayorista, la bajada del IVA de forma permanente, el control de las ofertas fraudulentas de las eléctricas, y la aprobación de un nuevo modelo de bono social que represente al menos un 50% de descuento en la factura y del que se puedan beneficiar las familias que cobren no más de dos salarios mínimos, que aumentarían hasta tres en función del número y características de miembros.\n\nLa OCU denuncia que la factura oculta el precio de la energía\n\nPor otra parte, la Organización de Consumidores y Usuarios (OCU) ha denunciado que la factura de la tarifa regulada (PVPC) oculta el precio de la energía.\n\nEn un comunicado, la asociación señala que bajo el epígrafe \'coste de la energía\', la factura de los hogares con tarifa regulada PVPC recoge únicamente el importe  ...

# %%
tokens=word_tokenize(textfile)

# %%
tokens[:20]
# Out:
# ['La',
#  'luz',
#  'se',
#  'encarece',
#  'un',
#  '35',
#  '%',
#  'en',
#  'la',
#  'primera',
#  'quincena',
#  'de',
#  'julio',
#  'y',
#  'la',
#  'OCU',
#  'denuncia',
#  'que',
#  'la',
#  'factura']

# %%
len(tokens)
# Out:
# 892

# %%
fdist1=nltk.FreqDist(tokens)

# %%
word_freq=dict((word,freq)for word, freq in fdist1.items() if not word.isdigit())

# %%
word_freq
# Out:
# {'La': 6,
#  'luz': 5,
#  'se': 9,
#  'encarece': 1,
#  'un': 12,
#  '%': 9,
#  'en': 26,
#  'la': 46,
#  'primera': 2,
#  'quincena': 2,
#  'de': 68,
#  'julio': 7,
#  'y': 14,
#  'OCU': 4,
#  'denuncia': 2,
#  'que': 20,
#  'factura': 11,
#  'oculta': 3,
#  'el': 33,
#  'precio': 9,
#  'energía': 5,
#  'Así': 3,
#  'con': 7,
#  'las': 10,
#  'tarifas': 5,
#  'los': 17,
#  'quince': 2,
#  'primeros': 3,
#  'días': 3,
#  'este': 3,
#  'mes': 3,
#  ',': 39,
#  'usuario': 6,
#  'medio': 8,
#  'pagará': 2,
#  '21,68': 2,
#  'euros': 14,
#  'más': 9,
#  'cuando': 3,
#  'situó': 3,
#  '62,67': 2,
#  '.': 21,
#  'NOTICIA': 1,
#  'ACTUALIZADA': 1,
#  '16/7/2021': 1,
#  'A': 1,
#  'LAS': 1,
#  '12:00': 1,
#  'HERALDO.ES': 1,
#  'Teresa': 1,
#  'Ribera': 1,
#  'asegura': 1,
#  'seguirá': 1,
#  'su': 2,
#  'línea': 1,
#  'durante': 1,
#  'meses': 1,
#  'ha': 6,
#  'encarecido': 1,
#  '34,6': 1,
#  'respecto': 1,
#  'al': 5,
#  'mismo': 1,
#  'del': 14,
#  'año': 2,
#  'pasado': 1,
#  'según': 2,
#  'datos': 1,
#  'Facua-Consumidores': 1,
#  'Acción': 1,
#  'ADVERTISING': 2,
#  'Según': 1,
#  'estimaciones': 1,
#  'asociación': 5,
#  'consumidores': 1,
#  'sobre': 3,
#  'evolución': 1,
#  'tarifa': 5,
#  'semirregulada': 1,
#  '(': 8,
#  'PVPC': 5,
#  ')': 8,
#  'seguir': 2,
#  'así': 2,
#  'mensual': 1,
#  'situaría': 1,
#  '84,35': 1,
#  'importe': 2,
#  'recibo': 3,
#  'aún': 1,
#  'elevado': 1,
#  'junio': 1,
#  'fue': 1,
#  '81,27': 1,
#  'estima': 1,
#  'bajada': 3,
#  'IVA': 3,
#  'hasta': 2,
#  'diciembre': 1,
#  'mientras': 1,
#  'megavatio': 1,
#  'hora': 3,
#  'esté': 1,
#  'por': 4,
#  'encima': 1,
#  'amortiguado': 1,
#  'subida': 1,
#  '8,44': 1,
#  'Si': 1,
#  'siguiera': 1,
#  'aplicando': 1,
#  'habría': 1,
#  'batido': 1,
#  'todos': 1,
#  'récords': 1,
#  'alcanzado': 1,
#  '92,79': 1,
#  'MÁS': 1,
#  'INFORMACIÓN': 1,
#  'Lavadora': 1,
#  'lavavajillas': 2,
#  'o': 2,
#  'aire': 1,
#  'acondicionado': 1,
#  ':': 1,
#  'cuánto': 1,
#  'podemos': 1,
#  'ahorrar': 1,
#  '¿A': 1,
#  'qué': 1,
#  'será': 2,
#  'barato': 1,
#  'poner': 1,
#  'lavadora': 1,
#  'nueva': 1,
#  '?': 1,
#  'De': 1,
#  'tercer': 1,
#  'caro': 1,
#  'a': 3,
#  'nivel': 1,
#  'histórico': 1,
#  'para': 2,
#  'Hasta': 1,
#  'fecha': 1,
#  'cinco': 1,
#  'facturas': 1,
#  'elevadas': 1,
#  'han': 1,
#  'sido': 3,
#  '88,66': 1,
#  'primer': 1,
#  'trimestre': 1,
#  '87,81': 1,
#  'enero': 1,
#  '83,55': 1,
#  'septiembre': 1,
#  '82,13': 1,
#  'mayo': 1,
#  '81,55': 1,
#  'febrero': 1,
#  'El': 1,
#  'utilizado': 1,
#  'Facua': 2,
#  'sus': 1,
#  'análisis': 1,
#  'tiene': 1,
#  'una': 2,
#  'potencia': 1,
#  'contratada': 1,
#  '4,4': 1,
#  'kilovatios': 2,
#  'kW': 1,
#  '-la': 1,
#  'misma': 1,
#  'horario': 8,
#  'punta': 4,
#  'valle-': 1,
#  'consumo': 5,
#  'kWh': 2,
#  'mensuales': 1,
#  'En': 4,
#  'cuanto': 1,
#  'porcentajes': 1,
#  'tres': 3,
#  'tramos': 4,
#  'horarios': 3,
#  'nuevo': 2,
#  'sistema': 1,
#  'facturación': 2,
#  'toma': 1,
#  'como': 2,
#  'referencia': 1,
#  'perfil': 1,
#  'tradicional': 1,
#  'sin': 1,
#  'discriminación': 1,
#  'horaria': 1,
#  'publicado': 1,
#  'Comisión': 1,
#  'Nacional': 1,
#  'Mercados': 1,
#  'Competencia': 1,
#  'CNMC': 1,
#  'consume': 1,
#  'electricidad': 1,
#  'valle': 3,
#  'llano': 3,
#  'SUBIDA': 1,
#  'DEL': 1,
#  'KWH': 1,
#  'lo': 2,
#  'va': 1,
#  'media': 2,
#  '11,88': 1,
#  'céntimos': 5,
#  '13,43': 1,
#  '17,76': 1,
#  '28,86': 1,
#  'aritmética': 1,
#  'entre': 2,
#  '20,02': 1,
#  '68,5': 1,
#  'hace': 1,
#  'convocado': 1,
#  'jueves': 1,
#  'concentraciones': 1,
#  'contra': 1,
#  'tarifazo': 1,
#  'eléctrico': 2,
#  'capitales': 1,
#  'ciudad': 1,
#  'autónoma': 1,
#  'Melilla': 1,
#  'plantea': 1,
#  'decálogo': 1,
#  'reivindicaciones': 1,
#  'Gobierno': 1,
#  'ellas': 1,
#  'cambio': 2,
#  'reglas': 1,
#  'subasta': 1,
#  'mercado': 2,
#  'mayorista': 1,
#  'forma': 1,
#  'permanente': 1,
#  'control': 1,
#  'ofertas': 1,
#  'fraudulentas': 1,
#  'eléctricas': 1,
#  'aprobación': 1,
#  'modelo': 1,
#  'bono': 1,
#  'social': 1,
#  'represente': 1,
#  'menos': 1,
#  'descuento': 1,
#  'puedan': 1,
#  'beneficiar': 1,
#  'familias': 1,
#  'cobren': 1,
#  'no': 2,
#  'dos': 1,
#  'salarios': 1,
#  'mínimos': 1,
#  'aumentarían': 1,
#  'función': 1,
#  'número': 1,
#  'características': 1,
#  'miembros': 1,
#  'Por': 2,
#  'otra': 1,
#  'parte': 1,
#  'Organización': 1,
#  'Consumidores': 1,
#  'Usuarios': 1,
#  'denunciado': 1,
#  'regulada': 4,
#  'comunicado': 1,
#  'señala': 1,
#  'bajo': 1,
#  'epígrafe': 1,
#  "'coste": 1,
#  "'": 1,
#  'hogares': 1,
#  'recoge': 1,
#  'únicamente': 1,
#  'total': 1,
#  'facturar': 1,
#  'consta': 1,
#  'detallado': 1,
#  'cada': 2,
#  'uno': 1,
#  'cree': 1,
#  'esta': 1,
#  'falta': 1,
#  'detalle': 1,
#  'dificulta': 1,
#  'hábitos': 1,
#  'pretendía': 1,
#  'reciente': 2,
#  'reforma': 1,
#  'normativa': 2,
#  'e': 1,
#  'impide': 1,
#  'comparar': 1,
#  'libre': 2,
#  '``': 1,
#  'lastra': 1,
#  'competencia': 1,
#  "''": 1,
#  'ello': 1,
#  'solicita': 1,
#  'Ministerio': 1,
#  'Transición': 1,
#  'Ecológica': 1,
#  'rectificar': 1,
#  'reorganice': 1,
#  'información': 1,
#  'recogiendo': 1,
#  'tanto': 1,
#  'desglose': 1,
#  'concepto': 1,
#  'peaje': 1,
#  'cargos': 1,
#  'suma': 1}

# %% [markdown]
# # cleaning/ wrangling steps:

# %% [markdown]
# - prepositions -for/in/the/a/in -'stop words'
# - pronouns - personal i you be - not sure it adds meaning
# - stemming - racing horses and race horses
# - punctuaction - 51 ,s and 52 .s
# - lower case - Animal and animals
# - up to you re text (whats in the text) and purpose

# %%
sorted= sorted(word_freq.items(), key=lambda x:x[1], reverse=True)

# %%
sorted
# Out:
# [('de', 68),
#  ('la', 46),
#  (',', 39),
#  ('el', 33),
#  ('en', 26),
#  ('.', 21),
#  ('que', 20),
#  ('los', 17),
#  ('y', 14),
#  ('euros', 14),
#  ('del', 14),
#  ('un', 12),
#  ('factura', 11),
#  ('las', 10),
#  ('se', 9),
#  ('%', 9),
#  ('precio', 9),
#  ('más', 9),
#  ('medio', 8),
#  ('(', 8),
#  (')', 8),
#  ('horario', 8),
#  ('julio', 7),
#  ('con', 7),
#  ('La', 6),
#  ('usuario', 6),
#  ('ha', 6),
#  ('luz', 5),
#  ('energía', 5),
#  ('tarifas', 5),
#  ('al', 5),
#  ('asociación', 5),
#  ('tarifa', 5),
#  ('PVPC', 5),
#  ('consumo', 5),
#  ('céntimos', 5),
#  ('OCU', 4),
#  ('por', 4),
#  ('punta', 4),
#  ('En', 4),
#  ('tramos', 4),
#  ('regulada', 4),
#  ('oculta', 3),
#  ('Así', 3),
#  ('primeros', 3),
#  ('días', 3),
#  ('este', 3),
#  ('mes', 3),
#  ('cuando', 3),
#  ('situó', 3),
#  ('sobre', 3),
#  ('recibo', 3),
#  ('bajada', 3),
#  ('IVA', 3),
#  ('hora', 3),
#  ('a', 3),
#  ('sido', 3),
#  ('tres', 3),
#  ('horarios', 3),
#  ('valle', 3),
#  ('llano', 3),
#  ('primera', 2),
#  ('quincena', 2),
#  ('denuncia', 2),
#  ('quince', 2),
#  ('pagará', 2),
#  ('21,68', 2),
#  ('62,67', 2),
#  ('su', 2),
#  ('año', 2),
#  ('según', 2),
#  ('ADVERTISING', 2),
#  ('seguir', 2),
#  ('así', 2),
#  ('importe', 2),
#  ('hasta', 2),
#  ('lavavajillas', 2),
#  ('o', 2),
#  ('será', 2),
#  ('para', 2),
#  ('Facua', 2),
#  ('una', 2),
#  ('kilovatios', 2),
#  ('kWh', 2),
#  ('nuevo', 2),
#  ('facturación', 2),
#  ('como', 2),
#  ('lo', 2),
#  ('media', 2),
#  ('entre', 2),
#  ('eléctrico', 2),
#  ('cambio', 2),
#  ('mercado', 2),
#  ('no', 2),
#  ('Por', 2),
#  ('cada', 2),
#  ('reciente', 2),
#  ('normativa', 2),
#  ('libre', 2),
#  ('encarece', 1),
#  ('NOTICIA', 1),
#  ('ACTUALIZADA', 1),
#  ('16/7/2021', 1),
#  ('A', 1),
#  ('LAS', 1),
#  ('12:00', 1),
#  ('HERALDO.ES', 1),
#  ('Teresa', 1),
#  ('Ribera', 1),
#  ('asegura', 1),
#  ('seguirá', 1),
#  ('línea', 1),
#  ('durante', 1),
#  ('meses', 1),
#  ('encarecido', 1),
#  ('34,6', 1),
#  ('respecto', 1),
#  ('mismo', 1),
#  ('pasado', 1),
#  ('datos', 1),
#  ('Facua-Consumidores', 1),
#  ('Acción', 1),
#  ('Según', 1),
#  ('estimaciones', 1),
#  ('consumidores', 1),
#  ('evolución', 1),
#  ('semirregulada', 1),
#  ('mensual', 1),
#  ('situaría', 1),
#  ('84,35', 1),
#  ('aún', 1),
#  ('elevado', 1),
#  ('junio', 1),
#  ('fue', 1),
#  ('81,27', 1),
#  ('estima', 1),
#  ('diciembre', 1),
#  ('mientras', 1),
#  ('megavatio', 1),
#  ('esté', 1),
#  ('encima', 1),
#  ('amortiguado', 1),
#  ('subida', 1),
#  ('8,44', 1),
#  ('Si', 1),
#  ('siguiera', 1),
#  ('aplicando', 1),
#  ('habría', 1),
#  ('batido', 1),
#  ('todos', 1),
#  ('récords', 1),
#  ('alcanzado', 1),
#  ('92,79', 1),
#  ('MÁS', 1),
#  ('INFORMACIÓN', 1),
#  ('Lavadora', 1),
#  ('aire', 1),
#  ('acondicionado', 1),
#  (':', 1),
#  ('cuánto', 1),
#  ('podemos', 1),
#  ('ahorrar', 1),
#  ('¿A', 1),
#  ('qué', 1),
#  ('barato', 1),
#  ('poner', 1),
#  ('lavadora', 1),
#  ('nueva', 1),
#  ('?', 1),
#  ('De', 1),
#  ('tercer', 1),
#  ('caro', 1),
#  ('nivel', 1),
#  ('histórico', 1),
#  ('Hasta', 1),
#  ('fecha', 1),
#  ('cinco', 1),
#  ('facturas', 1),
#  ('elevadas', 1),
#  ('han', 1),
#  ('88,66', 1),
#  ('primer', 1),
#  ('trimestre', 1),
#  ('87,81', 1),
#  ('enero', 1),
#  ('83,55', 1),
#  ('septiembre', 1),
#  ('82,13', 1),
#  ('mayo', 1),
#  ('81,55', 1),
#  ('febrero', 1),
#  ('El', 1),
#  ('utilizado', 1),
#  ('sus', 1),
#  ('análisis', 1),
#  ('tiene', 1),
#  ('potencia', 1),
#  ('contratada', 1),
#  ('4,4', 1),
#  ('kW', 1),
#  ('-la', 1),
#  ('misma', 1),
#  ('valle-', 1),
#  ('mensuales', 1),
#  ('cuanto', 1),
#  ('porcentajes', 1),
#  ('sistema', 1),
#  ('toma', 1),
#  ('referencia', 1),
#  ('perfil', 1),
#  ('tradicional', 1),
#  ('sin', 1),
#  ('discriminación', 1),
#  ('horaria', 1),
#  ('publicado', 1),
#  ('Comisión', 1),
#  ('Nacional', 1),
#  ('Mercados', 1),
#  ('Competencia', 1),
#  ('CNMC', 1),
#  ('consume', 1),
#  ('electricidad', 1),
#  ('SUBIDA', 1),
#  ('DEL', 1),
#  ('KWH', 1),
#  ('va', 1),
#  ('11,88', 1),
#  ('13,43', 1),
#  ('17,76', 1),
#  ('28,86', 1),
#  ('aritmética', 1),
#  ('20,02', 1),
#  ('68,5', 1),
#  ('hace', 1),
#  ('convocado', 1),
#  ('jueves', 1),
#  ('concentraciones', 1),
#  ('contra', 1),
#  ('tarifazo', 1),
#  ('capitales', 1),
#  ('ciudad', 1),
#  ('autónoma', 1),
#  ('Melilla', 1),
#  ('plantea', 1),
#  ('decálogo', 1),
#  ('reivindicaciones', 1),
#  ('Gobierno', 1),
#  ('ellas', 1),
#  ('reglas', 1),
#  ('subasta', 1),
#  ('mayorista', 1),
#  ('forma', 1),
#  ('permanente', 1),
#  ('control', 1),
#  ('ofertas', 1),
#  ('fraudulentas', 1),
#  ('eléctricas', 1),
#  ('aprobación', 1),
#  ('modelo', 1),
#  ('bono', 1),
#  ('social', 1),
#  ('represente', 1),
#  ('menos', 1),
#  ('descuento', 1),
#  ('puedan', 1),
#  ('beneficiar', 1),
#  ('familias', 1),
#  ('cobren', 1),
#  ('dos', 1),
#  ('salarios', 1),
#  ('mínimos', 1),
#  ('aumentarían', 1),
#  ('función', 1),
#  ('número', 1),
#  ('características', 1),
#  ('miembros', 1),
#  ('otra', 1),
#  ('parte', 1),
#  ('Organización', 1),
#  ('Consumidores', 1),
#  ('Usuarios', 1),
#  ('denunciado', 1),
#  ('comunicado', 1),
#  ('señala', 1),
#  ('bajo', 1),
#  ('epígrafe', 1),
#  ("'coste", 1),
#  ("'", 1),
#  ('hogares', 1),
#  ('recoge', 1),
#  ('únicamente', 1),
#  ('total', 1),
#  ('facturar', 1),
#  ('consta', 1),
#  ('detallado', 1),
#  ('uno', 1),
#  ('cree', 1),
#  ('esta', 1),
#  ('falta', 1),
#  ('detalle', 1),
#  ('dificulta', 1),
#  ('hábitos', 1),
#  ('pretendía', 1),
#  ('reforma', 1),
#  ('e', 1),
#  ('impide', 1),
#  ('comparar', 1),
#  ('``', 1),
#  ('lastra', 1),
#  ('competencia', 1),
#  ("''", 1),
#  ('ello', 1),
#  ('solicita', 1),
#  ('Ministerio', 1),
#  ('Transición', 1),
#  ('Ecológica', 1),
#  ('rectificar', 1),
#  ('reorganice', 1),
#  ('información', 1),
#  ('recogiendo', 1),
#  ('tanto', 1),
#  ('desglose', 1),
#  ('concepto', 1),
#  ('peaje', 1),
#  ('cargos', 1),
#  ('suma', 1)]

# %%
clean_words=[word for word in tokens if word.isalpha()]

# %%
clean_words[:10]
# Out:
# ['La', 'luz', 'se', 'encarece', 'un', 'en', 'la', 'primera', 'quincena', 'de']

# %%
lower_words=[word.lower() for word in clean_words]

# %%
lower_words[:10]
# Out:
# ['la', 'luz', 'se', 'encarece', 'un', 'en', 'la', 'primera', 'quincena', 'de']

# %%
from nltk.corpus import stopwords

# %%
stop_words=stopwords.words('english')

# %%
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
words_without_stop=[word for word in lower_words if not word in stop_words]

# %%
len(words_without_stop)
# Out:
# 733

# %%
fdist2=nltk.FreqDist(words_without_stop)

# %%
fdist2.most_common(20)
# Out:
# [('de', 69),
#  ('la', 52),
#  ('el', 34),
#  ('en', 30),
#  ('que', 20),
#  ('los', 17),
#  ('del', 15),
#  ('euros', 14),
#  ('un', 12),
#  ('factura', 11),
#  ('las', 11),
#  ('más', 10),
#  ('se', 9),
#  ('precio', 9),
#  ('medio', 8),
#  ('horario', 8),
#  ('julio', 7),
#  ('con', 7),
#  ('usuario', 6),
#  ('ha', 6)]

# %%
textlist=Text(words_without_stop)

# %%
#convert words into nltk language

# %%
type(textlist)
# Out:
# nltk.text.Text

# %%
#words that frequently appear together (phrases)
textlist.collocations()
# Out:
# usuario medio; las tarifas; regulada pvpc; tarifa regulada; primeros
# días; los euros; tramos horarios; primera quincena; bajada del; del
# iva; horario punta; quince primeros; ocu denuncia; seguir así; este
# mes; medio pagará; tres tramos; con las; pagará euros; del mercado

# %%
# find fragments containing key words - annother index is created - so searching is faster next time
textlist.concordance('tramos')
# Out:
# Displaying 4 of 4 matches:
#  porcentajes de consumo en los tres tramos horarios del nuevo sistema de factu
#  la media aritmética entre los tres tramos ha sido de céntimos un más que hace
# onsumo eléctrico en cada uno de los tramos horarios punta llano valle ocu cree
# ue se reorganice la información por tramos horarios recogiendo tanto el desglo

# %%
#lexical dispersion plot - analyses appearence of words
textlist.dispersion_plot(['precio', 'horarios','tramos', 'media'])

# %%
from textblob import TextBlob

# %%
clothingdf=pd.read_csv()

# %%
clothingdf['sentiment']=clothingdf['Review Text'].apply(lambda x: TextBlob(x).sentiment.polarity)
