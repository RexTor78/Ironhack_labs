# %%
import pandas as pd
import numpy as np
import re

data= pd.read_csv("C:\\Users\hecto\PreWorks\W2\Project/alldata.csv")

# %%
data.head(20)
# Out:
#                                              position              company  \
# 0                                Development Director              ALS TDI
# 1   An Ostentatiously-Excitable Principal Research...   The Hexagon Lavish
# 2                                      Data Scientist       Xpert Staffing
# 3                                        Data Analyst       Operation HOPE
# 4   Assistant Professor -TT - Signal Processing & ...     Emory University
# 5                         Manager of Data Engineering   McKinsey & Company
# 6        Product Specialist - Periscope, New Ventures   McKinsey & Company
# 7   Junior to Mid-level Engineer, Geologist or Env...                 Wood
# 8                       Analyst - CIB Credit Research             SunTrust
# 9   Senior Associate - Cognitive Data Scientist Na...                 KPMG
# 10                       STATISTICAL FORECAST ANALYST       The Home Depot
# ...

# %%
data['location'].str.extract(r'([\D]+?[\D]+,\D\D)')
# Out:
#                  0
# 0       Atlanta, G
# 1       Atlanta, G
# 2       Atlanta, G
# 3       Atlanta, G
# 4       Atlanta, G
# ...            ...
# 6959  Sunnyvale, C
# 6960  Sunnyvale, C
# 6961  Sunnyvale, C
# 6962  Sunnyvale, C
# 6963  Sunnyvale, C
#
# [6964 rows x 1 columns]

# %%
data['city,state']=data['location'].str

# %%
data['state']=data['city,state'].str[-2:]

# %%
## position
data
# Out:
#                                                position  \
# 0                                  Development Director
# 1     An Ostentatiously-Excitable Principal Research...
# 2                                        Data Scientist
# 3                                          Data Analyst
# 4     Assistant Professor -TT - Signal Processing & ...
# ...                                                 ...
# 6959          Data Developer / Machine Learning Analyst
# 6960                                        Scientist I
# 6961                                   Intern Scientist
# 6962                    Senior Data & Applied Scientist
# 6963            Principal Data Scientist, Deep Learning
#
#                                company  \
# 0                              ALS TDI
# 1                   The Hexagon Lavish
# 2                       Xpert Staffing
# 3                       Operation HOPE
# 4                     Emory University
# ...                                ...
# ...

# %%
#re.IGNOREcase

data['position']. str.findall('data scientist', flags=re.IGNORECASE)
# Out:
# 0                     []
# 1                     []
# 2       [Data Scientist]
# 3                     []
# 4                     []
#               ...
# 6959                  []
# 6960                  []
# 6961                  []
# 6962                  []
# 6963    [Data Scientist]
# Name: position, Length: 6964, dtype: object

# %%
data['ds yes']=data['position'].str.count('data scientist', flags=re.IGNORECASE)

# %%
data['ds yes'].value_counts()
# Out:
# 0.0    5692
# 1.0    1252
# 2.0       9
# Name: ds yes, dtype: int64

# %%
data['description'].head()
# Out:
# 0    Development Director\nALS Therapy Development ...
# 1    Job Description\n\n"The road that leads to acc...
# 2    Growing company located in the Atlanta, GA are...
# 3    DEPARTMENT: Program OperationsPOSITION LOCATIO...
# 4    DESCRIPTION\nThe Emory University Department o...
# Name: description, dtype: object

# %%
data['description'].str.findall(r'\d+\s\byears\b|[\d]+\S?[\d]+\s\byears\b')
# Out:
# 0                       [6-8 years]
# 1                                []
# 2                                []
# 3                        [25 years]
# 4                                []
#                    ...
# 6959             [5 years, 7 years]
# 6960                      [5 years]
# 6961                             []
# 6962                             []
# 6963    [5 years, 3 years, 2 years]
# Name: description, Length: 6964, dtype: object

# %%
data['description'].str.findall(r'\d+\s\w+|[\d]+\S?[\d]+\s\w+')
# Out:
# 0                                             [6-8 years]
# 1                                                      []
# 2                                                      []
# 3       [25 years, 000.00 to, 2 yearsbasic, 2 yearsPro...
# 4                                                 [10 of]
#                               ...
# 6959                   [5 years, 5 to, 7 years, 40 hours]
# 6960    [200 clinical, 20 different, 1,200 Pharmacycli...
# 6961                                                   []
# 6962                                                   []
# 6963    [1 platform, 5 years, 3 years, 2 years, 2-5 pe...
# Name: description, Length: 6964, dtype: object

# %%
data['description'].str.findall(r'\d+\s\byears\b|[\d]+\S?[\d]+\s\byears\b')
# Out:
# 0                       [6-8 years]
# 1                                []
# 2                                []
# 3                        [25 years]
# 4                                []
#                    ...
# 6959             [5 years, 7 years]
# 6960                      [5 years]
# 6961                             []
# 6962                             []
# 6963    [5 years, 3 years, 2 years]
# Name: description, Length: 6964, dtype: object

# %%
data['description'].str.contains(r'\d+\s\byears\b')
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 6959     True
# 6960     True
# 6961    False
# 6962    False
# 6963     True
# Name: description, Length: 6964, dtype: object

# %%
data['remote'] = data['description'].str.contains(r'(\bremote\b)', flags = re.IGNORECASE)
data['remote'].value_counts()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# False    6581
# True      372
# Name: remote, dtype: int64

# %%
data['interpersonal'] = data['description'].str.contains(r'(\binterpersonal\b)', flags = re.IGNORECASE)
data['interpersonal'].value_counts()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# False    5930
# True     1023
# Name: interpersonal, dtype: int64

# %%
if contains([motivation],"analysis") then "analy" elseif contains([motivation],"analyses")then "analy" elseif contains([motivation],"analyze") then "analy" END
