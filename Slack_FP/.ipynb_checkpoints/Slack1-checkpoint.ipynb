# %%
import json
import pandas as pd
import numpy as np
import os

# %%
data=json.load(open('slack/general/2021-07-20.json'))
# with open('channels.json', "r") as read_file:
    #data = json.load(read_file)

# %%
data[0]['attachments'][0]['title_link']
# Out:
# 'https://colab.research.google.com/notebooks/intro.ipynb?utm_source=scs-index'

# %%
data[0]
# Out:
# {'client_msg_id': '2f051981-3dcd-42f4-bf95-388af3501e53',
#  'type': 'message',
#  'text': '<!here> after lunch at 2pm, be ready to go with EITHER : keras and tensor flow installed on your conda environment (pls check they are working), or set up and ready on <https://colab.research.google.com/notebooks/intro.ipynb?utm_source=scs-index|google colab> (straightforward with a google account)',
#  'user': 'U021UNQGZC4',
#  'ts': '1626778947.043000',
#  'team': 'T021KE79B9B',
#  'user_team': 'T021KE79B9B',
#  'source_team': 'T021KE79B9B',
#  'user_profile': {'avatar_hash': 'f30ef9a9abe2',
#   'image_72': 'https://avatars.slack-edge.com/2021-05-12/2049849835622_f30ef9a9abe22ef41bee_72.jpg',
#   'first_name': 'Sian',
#   'real_name': 'Sian Davies',
#   'display_name': 'Sian Davies',
#   'team': 'T021KE79B9B',
#   'name': 'sian.davies',
#   'is_restricted': False,
#   'is_ultra_restricted': False},
#  'attachments': [{'title': 'Google Colaboratory',
# ...

# %%
data[0]['reactions'][0]['users'][0]
# Out:
# 'U021CE3UWPR'

# %%
data
# Out:
# [{'client_msg_id': '2f051981-3dcd-42f4-bf95-388af3501e53',
#   'type': 'message',
#   'text': '<!here> after lunch at 2pm, be ready to go with EITHER : keras and tensor flow installed on your conda environment (pls check they are working), or set up and ready on <https://colab.research.google.com/notebooks/intro.ipynb?utm_source=scs-index|google colab> (straightforward with a google account)',
#   'user': 'U021UNQGZC4',
#   'ts': '1626778947.043000',
#   'team': 'T021KE79B9B',
#   'user_team': 'T021KE79B9B',
#   'source_team': 'T021KE79B9B',
#   'user_profile': {'avatar_hash': 'f30ef9a9abe2',
#    'image_72': 'https://avatars.slack-edge.com/2021-05-12/2049849835622_f30ef9a9abe22ef41bee_72.jpg',
#    'first_name': 'Sian',
#    'real_name': 'Sian Davies',
#    'display_name': 'Sian Davies',
#    'team': 'T021KE79B9B',
#    'name': 'sian.davies',
#    'is_restricted': False,
#    'is_ultra_restricted': False},
#   'attachments': [{'title': 'Google Colaboratory',
# ...

# %%
from os import listdir
from os.path import isfile, join
test = [f for f in listdir('slack\general') if isfile(join('slack\general', f))]

# %%
test

# %%
date_time = []
user = []
text = []
file = []
reactions = []
replies = []
replies_time=[]
channel = []

for channel in channels:

    for file in test:
        data=json.load(open(channel + "/" + file+ ".json"))

        for message in data:
            date_time.append(message["ts"])
            user.append(message["user"])
            file.append("files" in message.keys())
            channel.append(channel)
            if replies in message:
                replies.append(message.['reply_users'])
            else: 0 break
            if reactions in message:
                reactions.append(
                    count=0
                    for users in gen[1]['reactions']:
                       count=count+users['count'])
            else: 0 break
            if replies in message:
                replies_time.append(['replies'][0]['ts'])
            else: 0 break

# %%
df_final = pd.DataFrame({"daytime":date_time,
                        "user": user})

# %%
"general/"+test[1]+".json"

# %%
test

# %%
test=[s.replace('.json','')for s in test]

# %%
test

# %%
for each in test(json):
    new = os.path.splitext(test)[0]
    json[index] = new

# %%
test

# %%
import os

dir_name = "general"
test = os.listdir(dir_name)

for item in test:
    if item.endswith(".json"):
        os.remove(os.path.join(dir_name, item))

# %%
test

# %%
len(data)

# %%
users=json.load(open('users.json'))
users

# %%
general=open('general/2021-07-14.json',encoding='utf-8')
gen=json.load(general)

# %%
gen

# %%
len(gen)

# %%
for user in gen:
    print(user.get('user'))

# %%
users.keys()

# %%
gen['client_msg_id']['user']

# %%
general=open('general/2021-05-12.json',encoding='utf-8')
gen=json.load(general)

# %%
df=pd.read_json('general/2021-05-12.json',encoding='utf-8')

# %%
df

# %%
import os

# %%
file_list = [file for file in os.listdir('general') if file.endswith('.json')]
gen = pd.DataFrame()
for file in file_list:
    gend=pd.read_json(('general/{}').format(file))
    gen = pd.concat([gen, gend], axis=0)

# %%
gend

# %%
gen.shape

# %%
gen

# %%
import os
arr = os.listdir('c:\\Users\hecto\PreWorks\Ironhack_labs\Final Project\Slack/.')
print(arr)

# %%
import os
dir='C:\\Users\hecto\PreWorks\Ironhack_labs\Slack_FP\Slack/'
fol = os.listdir(dir)
print(fol)

# %%
dchannels=[file for file in fol if file.endswith('json')]

# %%
print(channels)

# %%
channels=list(set(fol)-set(dchannels))

# %%
channels

# %%
users=json.load(open('slack/users.json'))

# %%
users[32].keys()
# Out:
# dict_keys(['id', 'team_id', 'name', 'deleted', 'color', 'real_name', 'tz', 'tz_label', 'tz_offset', 'profile', 'is_admin', 'is_owner', 'is_primary_owner', 'is_restricted', 'is_ultra_restricted', 'is_bot', 'is_app_user', 'updated', 'is_email_confirmed'])

# %%
user_id=[]
name=[]
for user in users:
    user_id.append(user['id'])
    if 'real_name' in user.keys():
        name.append(user['real_name'])
    else:
        name.append(0)

# %%
name
# Out:
# ['Madini Liebscher',
#  'Hector Santos',
#  'miguel.simon',
#  'Lucas',
#  'Pedro Pablo Errazuriz',
#  'Google Calendar',
#  'Axana Raiser',
#  'Jonas Tonndorff',
#  'Gellért Bodorkós',
#  'Ángela Sánchez',
#  0,
#  'AnnaBeteta',
#  'Andrea Fought',
#  'Sian Davies',
#  'Florian Titze',
#  'martamarti DA BAR JUN2021',
#  'Andre Novikov',
#  'Uroš Petković',
#  'Sathiya Raju',
#  'Dámaris Clariana',
#  'Jennifer Dersjant',
#  'Fernando Arancibia',
#  'Julia León',
#  0,
#  'Nayib Rivera',
#  'Majed Ayoub Alqawasmi',
#  'Cguimaraes Leticia',
#  'Walter Conde',
#  'Google Drive',
#  'Miro',
#  'GitHub',
#  'Brett Hunt',
#  'trello',
#  'Polly']

# %%
users=pd.DataFrame({'id':user_id,'name':name})

# %%
users.drop_duplicates(subset="name")
# Out:
#              id                       name
# 0   U0217P72YR5           Madini Liebscher
# 1   U021CE3UWPR              Hector Santos
# 2   U021NHS652N               miguel.simon
# 3   U021Q53LBPX                      Lucas
# 4   U021Q54K3B7      Pedro Pablo Errazuriz
# 5   U021RRZM3K7            Google Calendar
# 6   U021T7DU0BC               Axana Raiser
# 7   U021TDD883V            Jonas Tonndorff
# 8   U021TDMBPRR           Gellért Bodorkós
# 9   U021TDMEH27             Ángela Sánchez
# 10  U021TDMHF5H                          0
# 11  U021TDMLNTD                 AnnaBeteta
# 12  U021TDN4RAP              Andrea Fought
# 13  U021UNQGZC4                Sian Davies
# 14  U021WEXHN4E              Florian Titze
# 15  U021ZC6H9GC  martamarti DA BAR JUN2021
# 16  U021ZC6JR28              Andre Novikov
# 17  U021ZC6L676              Uroš Petković
# 18  U0225RGM941               Sathiya Raju
# 19  U0225RHK6Q1           Dámaris Clariana
# 20  U0225RJ3Z4H          Jennifer Dersjant
# ...

# %%
users
