# %% [markdown]
# ## Spotipy API
#
# Create an Spotify account and follow these steps to register an app: https://developer.spotify.com/documentation/general/guides/app-settings/
#
# After the app is created, you can see it on your dashboard
# https://developer.spotify.com/dashboard/applications
#
# Click on it and you'll find the client id and client secret.

# %% [markdown]
# #### Authentification

# %%
import spotipy # install if needed
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="client_id",client_secret="client_secret"))

# %% [markdown]
# #### Searching songs with 'queries' with `sp.search`

# %%
results = sp.search(q='Jean Michael Jarre',limit=50)

# %% [markdown]
# Explore the object returned by the request:

# %%
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Jean+Michael+Jarre&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5MhLmv7GgyjbxGqiIGasvT'},
#        'href': 'https://api.spotify.com/v1/artists/5MhLmv7GgyjbxGqiIGasvT',
#        'id': '5MhLmv7GgyjbxGqiIGasvT',
#        'name': 'Jean-Michel Jarre',
#        'type': 'artist',
#        'uri': 'spotify:artist:5MhLmv7GgyjbxGqiIGasvT'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3e7TxckusgnC1AYnAqbl2z'},
#      'href': 'https://api.spotify.com/v1/albums/3e7TxckusgnC1AYnAqbl2z',
#      'id': '3e7TxckusgnC1AYnAqbl2z',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d51e6d66cda008f80104c821',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d51e6d66cda008f80104c821',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d51e6d66cda008f80104c821',
#        'width': 64}],
#      'name': 'Oxygène',
#      'release_date': '1976-12-02',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:3e7TxckusgnC1AYnAqbl2z'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5MhLmv7GgyjbxGqiIGasvT'},
#       'href': 'https://api.spotify.com/v1/artists/5MhLmv7GgyjbxGqiIGasvT',
#       'id': '5MhLmv7GgyjbxGqiIGasvT',
#       'name': 'Jean-Michel Jarre',
#       'type': 'artist',
#       'uri': 'spotify:artist:5MhLmv7GgyjbxGqiIGasvT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 246893,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR45F1100080'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0Tt2jli0yAD1MKSTb5MvS2'},
#     'href': 'https://api.spotify.com/v1/tracks/0Tt2jli0yAD1MKSTb5MvS2',
#     'id': '0Tt2jli0yAD1MKSTb5MvS2',
#     'is_local': False,
#     'name': 'Oxygene, Pt. 4',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9ca819e028d38fad38ab6894129bddee897b1c8f?cid=a53afe619a9e44ff836314256c747563',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0Tt2jli0yAD1MKSTb5MvS2'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Ovgaj3vPQnqHHO63l7tL5'},
#        'href': 'https://api.spotify.com/v1/artists/5Ovgaj3vPQnqHHO63l7tL5',
#        'id': '5Ovgaj3vPQnqHHO63l7tL5',
#        'name': 'Coeur de Glace',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Ovgaj3vPQnqHHO63l7tL5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4HuSYcGAntY1Fj7ZcKOhtr'},
#      'href': 'https://api.spotify.com/v1/albums/4HuSYcGAntY1Fj7ZcKOhtr',
#      'id': '4HuSYcGAntY1Fj7ZcKOhtr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a6d5995da7c7fa263871e679',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a6d5995da7c7fa263871e679',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a6d5995da7c7fa263871e679',
#        'width': 64}],
#      'name': 'Bal populaire',
#      'release_date': '2021-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:4HuSYcGAntY1Fj7ZcKOhtr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Ovgaj3vPQnqHHO63l7tL5'},
#       'href': 'https://api.spotify.com/v1/artists/5Ovgaj3vPQnqHHO63l7tL5',
#       'id': '5Ovgaj3vPQnqHHO63l7tL5',
#       'name': 'Coeur de Glace',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Ovgaj3vPQnqHHO63l7tL5'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Af2iG7nPUQuY2jWTHEW2X'},
#       'href': 'https://api.spotify.com/v1/artists/4Af2iG7nPUQuY2jWTHEW2X',
#       'id': '4Af2iG7nPUQuY2jWTHEW2X',
#       'name': 'Idris Makazu',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Af2iG7nPUQuY2jWTHEW2X'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 175394,
#     'explicit': False,
#     'external_ids': {'isrc': 'usx9p2039643'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2aUXeMnbiLpVY4MfB0Vit3'},
#     'href': 'https://api.spotify.com/v1/tracks/2aUXeMnbiLpVY4MfB0Vit3',
#     'id': '2aUXeMnbiLpVY4MfB0Vit3',
#     'is_local': False,
#     'name': 'Populaire',
#     'popularity': 17,
#     'preview_url': 'https://p.scdn.co/mp3-preview/77cfff5288c12f967365d1e0cf168a30c6c51d65?cid=a53afe619a9e44ff836314256c747563',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2aUXeMnbiLpVY4MfB0Vit3'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5MhLmv7GgyjbxGqiIGasvT'},
#        'href': 'https://api.spotify.com/v1/artists/5MhLmv7GgyjbxGqiIGasvT',
#        'id': '5MhLmv7GgyjbxGqiIGasvT',
#        'name': 'Jean-Michel Jarre',
#        'type': 'artist',
#        'uri': 'spotify:artist:5MhLmv7GgyjbxGqiIGasvT'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3e7TxckusgnC1AYnAqbl2z'},
#      'href': 'https://api.spotify.com/v1/albums/3e7TxckusgnC1AYnAqbl2z',
#      'id': '3e7TxckusgnC1AYnAqbl2z',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d51e6d66cda008f80104c821',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d51e6d66cda008f80104c821',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d51e6d66cda008f80104c821',
#        'width': 64}],
#      'name': 'Oxygène',
#      'release_date': '1976-12-02',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:3e7TxckusgnC1AYnAqbl2z'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5MhLmv7GgyjbxGqiIGasvT'},
#       'href': 'https://api.spotify.com/v1/artists/5MhLmv7GgyjbxGqiIGasvT',
#       'id': '5MhLmv7GgyjbxGqiIGasvT',
#       'name': 'Jean-Michel Jarre',
#       'type': 'artist',
#       'uri': 'spotify:artist:5MhLmv7GgyjbxGqiIGasvT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KM',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MR',
#      'MT',
#      'MU',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TV',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VN',
#      'WS',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 466306,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR45F1100060'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4roqhhRarPSjK7V9viFOVU'},
#     'href': 'https://api.spotify.com/v1/tracks/4roqhhRarPSjK7V9viFOVU',
#     'id': '4roqhhRarPSjK7V9viFOVU',
#     'is_local': False,
#     'name': 'Oxygene, Pt. 2',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d89ce01a9a32b329e621136499b58cddcb18918f?cid=a53afe619a9e44ff836314256c747563',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4roqhhRarPSjK7V9viFOVU'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0dK1wy5v9DDEnhndvlX8Il'},
#        'href': 'https://api.spotify.com/v1/artists/0dK1wy5v9DDEnhndvlX8Il',
#        'id': '0dK1wy5v9DDEnhndvlX8Il',
#        'name': 'HK',
#        'type': 'artist',
#        'uri': 'spotify:artist:0dK1wy5v9DDEnhndvlX8Il'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3ZuBEj9ppJe8GSdKaMTfMN'},
#        'href': 'https://api.spotify.com/v1/artists/3ZuBEj9ppJe8GSdKaMTfMN',
#        'id': '3ZuBEj9ppJe8GSdKaMTfMN',
#        'name': 'Nimo',
#        'type': 'artist',
#        'uri': 'spotify:artist:3ZuBEj9ppJe8GSdKaMTfMN'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5Ur7YK8KU8gD1lUquOMPaH'},
#      'href': 'https://api.spotify.com/v1/albums/5Ur7YK8KU8gD1lUquOMPaH',
#      'id': '5Ur7YK8KU8gD1lUquOMPaH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27340828b11da4ee7d2d1bb130f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0240828b11da4ee7d2d1bb130f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485140828b11da4ee7d2d1bb130f',
#        'width': 64}],
#      'name': 'Oxygen',
#      'release_date': '2020-04-17',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5Ur7YK8KU8gD1lUquOMPaH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0dK1wy5v9DDEnhndvlX8Il'},
#       'href': 'https://api.spotify.com/v1/artists/0dK1wy5v9DDEnhndvlX8Il',
#       'id': '0dK1wy5v9DDEnhndvlX8Il',
#       'name': 'HK',
#       'type': 'artist',
#       'uri': 'spotify:artist:0dK1wy5v9DDEnhndvlX8Il'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3ZuBEj9ppJe8GSdKaMTfMN'},
#       'href': 'https://api.spotify.com/v1/artists/3ZuBEj9ppJe8GSdKaMTfMN',
#       'id': '3ZuBEj9ppJe8GSdKaMTfMN',
#       'name': 'Nimo',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ZuBEj9ppJe8GSdKaMTfMN'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 178000,
#     'explicit': True,
#     'external_ids': {'isrc': 'DEKF22000599'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2NXZOsC1WQTT4mujZx4ck6'},
#     'href': 'https://api.spotify.com/v1/tracks/2NXZOsC1WQTT4mujZx4ck6',
#     'id': '2NXZOsC1WQTT4mujZx4ck6',
#     'is_local': False,
#     'name': 'Oxygen',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6cb7dbe62538fbd1954368bc222b4f28d181621b?cid=a53afe619a9e44ff836314256c747563',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2NXZOsC1WQTT4mujZx4ck6'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5MhLmv7GgyjbxGqiIGasvT'},
#        'href': 'https://api.spotify.com/v1/artists/5MhLmv7GgyjbxGqiIGasvT',
#        'id': '5MhLmv7GgyjbxGqiIGasvT',
#        'name': 'Jean-Michel Jarre',
#        'type': 'artist',
#        'uri': 'spotify:artist:5MhLmv7GgyjbxGqiIGasvT'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/41Dl68Kik63nV6zvn07NgY'},
#      'href': 'https://api.spotify.com/v1/albums/41Dl68Kik63nV6zvn07NgY',
#      'id': '41Dl68Kik63nV6zvn07NgY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733d70ce0abd4c2e65b4b54f23',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023d70ce0abd4c2e65b4b54f23',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513d70ce0abd4c2e65b4b54f23',
#        'width': 64}],
#      'name': 'Equinoxe',
#      'release_date': '1978-12',
#      'release_date_precision': 'month',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:41Dl68Kik63nV6zvn07NgY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5MhLmv7GgyjbxGqiIGasvT'},
#       'href': 'https://api.spotify.com/v1/artists/5MhLmv7GgyjbxGqiIGasvT',
#       'id': '5MhLmv7GgyjbxGqiIGasvT',
#       'name': 'Jean-Michel Jarre',
#       'type': 'artist',
#       'uri': 'spotify:artist:5MhLmv7GgyjbxGqiIGasvT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 232093,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR14F7800260'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3ZchdqDVsdeOq6PbHGt3MV'},
#     'href': 'https://api.spotify.com/v1/tracks/3ZchdqDVsdeOq6PbHGt3MV',
#     'id': '3ZchdqDVsdeOq6PbHGt3MV',
#     'is_local': False,
#     'name': 'Equinoxe, Pt. 5',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/172f5162771977d75bda61ff08d0fd6d2b959b88?cid=a53afe619a9e44ff836314256c747563',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:3ZchdqDVsdeOq6PbHGt3MV'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Uuw1MHNH56xL76bTOVJE8'},
#        'href': 'https://api.spotify.com/v1/artists/0Uuw1MHNH56xL76bTOVJE8',
#        'id': '0Uuw1MHNH56xL76bTOVJE8',
#        'name': 'Momus',
#        'type': 'artist',
#        'uri': 'spotify:artist:0Uuw1MHNH56xL76bTOVJE8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3CKxtBntope61lmWtMR7Z5'},
#      'href': 'https://api.spotify.com/v1/albums/3CKxtBntope61lmWtMR7Z5',
#      'id': '3CKxtBntope61lmWtMR7Z5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273007eeb488c3883c70f3a02c9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02007eeb488c3883c70f3a02c9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851007eeb488c3883c70f3a02c9',
#        'width': 64}],
#      'name': 'Folktronic',
#      'release_date': '2001',
#      'release_date_precision': 'year',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:3CKxtBntope61lmWtMR7Z5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Uuw1MHNH56xL76bTOVJE8'},
#       'href': 'https://api.spotify.com/v1/artists/0Uuw1MHNH56xL76bTOVJE8',
#       'id': '0Uuw1MHNH56xL76bTOVJE8',
#       'name': 'Momus',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Uuw1MHNH56xL76bTOVJE8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 164866,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMFME1928341'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7lKJCUDzUhI5uQUVzHmaYh'},
#     'href': 'https://api.spotify.com/v1/tracks/7lKJCUDzUhI5uQUVzHmaYh',
#     'id': '7lKJCUDzUhI5uQUVzHmaYh',
#     'is_local': False,
#     'name': 'Jarre in Hicksville',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f0b5787c78517c3fb38e392fdc384ccf054b9fe6?cid=a53afe619a9e44ff836314256c747563',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:7lKJCUDzUhI5uQUVzHmaYh'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5MhLmv7GgyjbxGqiIGasvT'},
#        'href': 'https://api.spotify.com/v1/artists/5MhLmv7GgyjbxGqiIGasvT',
#        'id': '5MhLmv7GgyjbxGqiIGasvT',
#        'name': 'Jean-Michel Jarre',
#        'type': 'artist',
#        'uri': 'spotify:artist:5MhLmv7GgyjbxGqiIGasvT'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3e7TxckusgnC1AYnAqbl2z'},
#      'href': 'https://api.spotify.com/v1/albums/3e7TxckusgnC1AYnAqbl2z',
#      'id': '3e7TxckusgnC1AYnAqbl2z',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d51e6d66cda008f80104c821',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d51e6d66cda008f80104c821',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d51e6d66cda008f80104c821',
#        'width': 64}],
#      'name': 'Oxygène',
#      'release_date': '1976-12-02',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:3e7TxckusgnC1AYnAqbl2z'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5MhLmv7GgyjbxGqiIGasvT'},
#       'href': 'https://api.spotify.com/v1/artists/5MhLmv7GgyjbxGqiIGasvT',
#       'id': '5MhLmv7GgyjbxGqiIGasvT',
#       'name': 'Jean-Michel Jarre',
#       'type': 'artist',
#       'uri': 'spotify:artist:5MhLmv7GgyjbxGqiIGasvT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 460640,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR45F7600100'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/75c7B7CF7n06YFSgnoxVMm'},
#     'href': 'https://api.spotify.com/v1/tracks/75c7B7CF7n06YFSgnoxVMm',
#     'id': '75c7B7CF7n06YFSgnoxVMm',
#     'is_local': False,
#     'name': 'Oxygene, Pt. 1',
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/29a19c7f764015a8328a2ed8d9bed2164267414f?cid=a53afe619a9e44ff836314256c747563',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:75c7B7CF7n06YFSgnoxVMm'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7c5wlQVkajxJG0X13D0Fpc'},
#        'href': 'https://api.spotify.com/v1/artists/7c5wlQVkajxJG0X13D0Fpc',
#        'id': '7c5wlQVkajxJG0X13D0Fpc',
#        'name': 'Patrick Juvet',
#        'type': 'artist',
#        'uri': 'spotify:artist:7c5wlQVkajxJG0X13D0Fpc'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0SVMPRBhzZmRJCj16rjxpX'},
#      'href': 'https://api.spotify.com/v1/albums/0SVMPRBhzZmRJCj16rjxpX',
#      'id': '0SVMPRBhzZmRJCj16rjxpX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a41e6feec9d9a024e60baed9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a41e6feec9d9a024e60baed9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a41e6feec9d9a024e60baed9',
#        'width': 64}],
#      'name': 'Love',
#      'release_date': '1973-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:0SVMPRBhzZmRJCj16rjxpX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7c5wlQVkajxJG0X13D0Fpc'},
#       'href': 'https://api.spotify.com/v1/artists/7c5wlQVkajxJG0X13D0Fpc',
#       'id': '7c5wlQVkajxJG0X13D0Fpc',
# ...
#        'type': 'artist',
#        'uri': 'spotify:artist:5MhLmv7GgyjbxGqiIGasvT'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1I15TUSEsDHXn4IIvDsFHe'},
#      'href': 'https://api.spotify.com/v1/albums/1I15TUSEsDHXn4IIvDsFHe',
#      'id': '1I15TUSEsDHXn4IIvDsFHe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ca09e2edf097c13c8399a43b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ca09e2edf097c13c8399a43b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ca09e2edf097c13c8399a43b',
#        'width': 64}],
#      'name': 'Les concerts en Chine 1981 (Live)',
#      'release_date': '2015-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1I15TUSEsDHXn4IIvDsFHe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5MhLmv7GgyjbxGqiIGasvT'},
#       'href': 'https://api.spotify.com/v1/artists/5MhLmv7GgyjbxGqiIGasvT',
#       'id': '5MhLmv7GgyjbxGqiIGasvT',
#       'name': 'Jean-Michel Jarre',
#       'type': 'artist',
#       'uri': 'spotify:artist:5MhLmv7GgyjbxGqiIGasvT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 239293,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR14F8200010'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5UBeEIUrTP2mUrfwWosPvD'},
#     'href': 'https://api.spotify.com/v1/tracks/5UBeEIUrTP2mUrfwWosPvD',
#     'id': '5UBeEIUrTP2mUrfwWosPvD',
#     'is_local': False,
#     'name': 'Souvenir de Chine',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/42183b7d048031fbd72c8524d25ee38d24fbb755?cid=a53afe619a9e44ff836314256c747563',
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:5UBeEIUrTP2mUrfwWosPvD'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/68yugEvb2pyCfAOyXVR7CU'},
#        'href': 'https://api.spotify.com/v1/artists/68yugEvb2pyCfAOyXVR7CU',
#        'id': '68yugEvb2pyCfAOyXVR7CU',
#        'name': 'Michael Jarrell',
#        'type': 'artist',
#        'uri': 'spotify:artist:68yugEvb2pyCfAOyXVR7CU'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4NzLn7UyhvBlgzhF7WwMM1'},
#        'href': 'https://api.spotify.com/v1/artists/4NzLn7UyhvBlgzhF7WwMM1',
#        'id': '4NzLn7UyhvBlgzhF7WwMM1',
#        'name': "L'Orchestre de la Suisse Romande",
#        'type': 'artist',
#        'uri': 'spotify:artist:4NzLn7UyhvBlgzhF7WwMM1'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/31rALqMKxBY8SoTJhNwJhn'},
#        'href': 'https://api.spotify.com/v1/artists/31rALqMKxBY8SoTJhNwJhn',
#        'id': '31rALqMKxBY8SoTJhNwJhn',
#        'name': 'Paul Meyer',
#        'type': 'artist',
#        'uri': 'spotify:artist:31rALqMKxBY8SoTJhNwJhn'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2OmtnJTgdAAVVe6moOqecH'},
#        'href': 'https://api.spotify.com/v1/artists/2OmtnJTgdAAVVe6moOqecH',
#        'id': '2OmtnJTgdAAVVe6moOqecH',
#        'name': 'François Leleux',
#        'type': 'artist',
#        'uri': 'spotify:artist:2OmtnJTgdAAVVe6moOqecH'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6duaKoFWgzQNgHlfmn3dHq'},
#        'href': 'https://api.spotify.com/v1/artists/6duaKoFWgzQNgHlfmn3dHq',
#        'id': '6duaKoFWgzQNgHlfmn3dHq',
#        'name': 'Emmanuel Pahud',
#        'type': 'artist',
#        'uri': 'spotify:artist:6duaKoFWgzQNgHlfmn3dHq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/06E3zaTAkXOm0U09ZxblOG'},
#      'href': 'https://api.spotify.com/v1/albums/06E3zaTAkXOm0U09ZxblOG',
#      'id': '06E3zaTAkXOm0U09ZxblOG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ff6b4146c213f73cab3bf4df',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ff6b4146c213f73cab3bf4df',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ff6b4146c213f73cab3bf4df',
#        'width': 64}],
#      'name': 'Jarrell: …prisme / incidences...',
#      'release_date': '2007-09-13',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:06E3zaTAkXOm0U09ZxblOG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/68yugEvb2pyCfAOyXVR7CU'},
#       'href': 'https://api.spotify.com/v1/artists/68yugEvb2pyCfAOyXVR7CU',
#       'id': '68yugEvb2pyCfAOyXVR7CU',
#       'name': 'Michael Jarrell',
#       'type': 'artist',
#       'uri': 'spotify:artist:68yugEvb2pyCfAOyXVR7CU'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/44MPF0BuqaYF2Kdtz9RVcG'},
#       'href': 'https://api.spotify.com/v1/artists/44MPF0BuqaYF2Kdtz9RVcG',
#       'id': '44MPF0BuqaYF2Kdtz9RVcG',
#       'name': 'Pascal Rophé',
#       'type': 'artist',
#       'uri': 'spotify:artist:44MPF0BuqaYF2Kdtz9RVcG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4NzLn7UyhvBlgzhF7WwMM1'},
#       'href': 'https://api.spotify.com/v1/artists/4NzLn7UyhvBlgzhF7WwMM1',
#       'id': '4NzLn7UyhvBlgzhF7WwMM1',
#       'name': "L'Orchestre de la Suisse Romande",
#       'type': 'artist',
#       'uri': 'spotify:artist:4NzLn7UyhvBlgzhF7WwMM1'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/31rALqMKxBY8SoTJhNwJhn'},
#       'href': 'https://api.spotify.com/v1/artists/31rALqMKxBY8SoTJhNwJhn',
#       'id': '31rALqMKxBY8SoTJhNwJhn',
#       'name': 'Paul Meyer',
#       'type': 'artist',
#       'uri': 'spotify:artist:31rALqMKxBY8SoTJhNwJhn'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5op5lFTO35qn3ioXKwBsnp'},
#       'href': 'https://api.spotify.com/v1/artists/5op5lFTO35qn3ioXKwBsnp',
#       'id': '5op5lFTO35qn3ioXKwBsnp',
#       'name': 'Hae-Sun Kang',
#       'type': 'artist',
#       'uri': 'spotify:artist:5op5lFTO35qn3ioXKwBsnp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2OmtnJTgdAAVVe6moOqecH'},
#       'href': 'https://api.spotify.com/v1/artists/2OmtnJTgdAAVVe6moOqecH',
#       'id': '2OmtnJTgdAAVVe6moOqecH',
#       'name': 'François Leleux',
#       'type': 'artist',
#       'uri': 'spotify:artist:2OmtnJTgdAAVVe6moOqecH'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6duaKoFWgzQNgHlfmn3dHq'},
#       'href': 'https://api.spotify.com/v1/artists/6duaKoFWgzQNgHlfmn3dHq',
#       'id': '6duaKoFWgzQNgHlfmn3dHq',
#       'name': 'Emmanuel Pahud',
#       'type': 'artist',
#       'uri': 'spotify:artist:6duaKoFWgzQNgHlfmn3dHq'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6yX3HigXXYXLv2auxRNkbB'},
#       'href': 'https://api.spotify.com/v1/artists/6yX3HigXXYXLv2auxRNkbB',
#       'id': '6yX3HigXXYXLv2auxRNkbB',
#       'name': 'Marino Formenti',
#       'type': 'artist',
#       'uri': 'spotify:artist:6yX3HigXXYXLv2auxRNkbB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 306253,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR46Y0752124'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0MzQFourV0v16PaXuSgqVy'},
#     'href': 'https://api.spotify.com/v1/tracks/0MzQFourV0v16PaXuSgqVy',
#     'id': '0MzQFourV0v16PaXuSgqVy',
#     'is_local': False,
#     'name': 'Trois Etudes de Debussy (1992): Pour les sonorités opposées (Orchestration)',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fa8765463b8fd251b2c5d8f2b546a514b7fca87b?cid=a53afe619a9e44ff836314256c747563',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0MzQFourV0v16PaXuSgqVy'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=Jean+Michael+Jarre&type=track&offset=50&limit=50',
#   'offset': 0,
#   'previous': None,
#   'total': 69}}

# %% [markdown]
# Explore a single song:

# %%
results['tracks']['items'][3]
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0dK1wy5v9DDEnhndvlX8Il'},
#     'href': 'https://api.spotify.com/v1/artists/0dK1wy5v9DDEnhndvlX8Il',
#     'id': '0dK1wy5v9DDEnhndvlX8Il',
#     'name': 'HK',
#     'type': 'artist',
#     'uri': 'spotify:artist:0dK1wy5v9DDEnhndvlX8Il'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3ZuBEj9ppJe8GSdKaMTfMN'},
#     'href': 'https://api.spotify.com/v1/artists/3ZuBEj9ppJe8GSdKaMTfMN',
#     'id': '3ZuBEj9ppJe8GSdKaMTfMN',
#     'name': 'Nimo',
#     'type': 'artist',
#     'uri': 'spotify:artist:3ZuBEj9ppJe8GSdKaMTfMN'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5Ur7YK8KU8gD1lUquOMPaH'},
#   'href': 'https://api.spotify.com/v1/albums/5Ur7YK8KU8gD1lUquOMPaH',
#   'id': '5Ur7YK8KU8gD1lUquOMPaH',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27340828b11da4ee7d2d1bb130f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0240828b11da4ee7d2d1bb130f',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485140828b11da4ee7d2d1bb130f',
#     'width': 64}],
#   'name': 'Oxygen',
#   'release_date': '2020-04-17',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5Ur7YK8KU8gD1lUquOMPaH'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0dK1wy5v9DDEnhndvlX8Il'},
#    'href': 'https://api.spotify.com/v1/artists/0dK1wy5v9DDEnhndvlX8Il',
#    'id': '0dK1wy5v9DDEnhndvlX8Il',
#    'name': 'HK',
#    'type': 'artist',
#    'uri': 'spotify:artist:0dK1wy5v9DDEnhndvlX8Il'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3ZuBEj9ppJe8GSdKaMTfMN'},
#    'href': 'https://api.spotify.com/v1/artists/3ZuBEj9ppJe8GSdKaMTfMN',
#    'id': '3ZuBEj9ppJe8GSdKaMTfMN',
#    'name': 'Nimo',
#    'type': 'artist',
#    'uri': 'spotify:artist:3ZuBEj9ppJe8GSdKaMTfMN'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RU',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'disc_number': 1,
#  'duration_ms': 178000,
#  'explicit': True,
#  'external_ids': {'isrc': 'DEKF22000599'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/2NXZOsC1WQTT4mujZx4ck6'},
#  'href': 'https://api.spotify.com/v1/tracks/2NXZOsC1WQTT4mujZx4ck6',
#  'id': '2NXZOsC1WQTT4mujZx4ck6',
#  'is_local': False,
#  'name': 'Oxygen',
#  'popularity': 34,
#  'preview_url': 'https://p.scdn.co/mp3-preview/6cb7dbe62538fbd1954368bc222b4f28d181621b?cid=a53afe619a9e44ff836314256c747563',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:2NXZOsC1WQTT4mujZx4ck6'}

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri" or an "id".
#
# - The `id` is an alphanumeric code, and it's the nuclear part of the identifier.
#
# - The `uri` contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The `url` is a link to the song on the Spotify web player.
#
# We'll use the `uri` in this code-along, but feel free to use whatever you think fits best your needs.

# %% [markdown]
# #### Searching multiple artists

# %%
artists = ["Jean Michael Jarre", "Queen", "Mike Olfield", 'Metallica','Vanessa Paradisse','Ludwig van Beethoven','Antonio Vivaldi']

# %% [markdown]
# #### Exploring the tracks

# %% [markdown]
# Function to get the artists involved in a song:

# %%
results=sp.search

# %% [markdown]
# Function to get the "id's" of the artists from a song:

# %% [markdown]
# ### Playlists
#
# We will need to collect a "database" of songs. Playlists are a good way to access relatively large amounts of songs.

# %%
playlist = sp.user_playlist_tracks("spotify", "0Swkgrsji8x4cQWoJ4kfo2")

# %%
playlist_2 = sp.user_playlist_tracks("spotify", "75GeX247deNdTX7zdyZDnU")

# %%
playlist_2["total"]

# %% [markdown]
# Function to extract all songs from a playlist

# %% [markdown]
# Function to extract just the uri's:

# %% [markdown]
# #### Pagination using "next"
#
# When you collect songs from a playlist using `sp.playlist_tracks`, you're limited by the `limit` parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter `offset` allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function `sp.next()` does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key `next` on the results from any request.

# %% [markdown]
# ### Audio features
#
# You can check here an explanation of the audio features: https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/

# %% [markdown]
# Above, we stored all the uri's of a playlist into a list called `iron_uris`. We're going to get all the audio features from that playlist's songs now.

# %% [markdown]
# ### Searching the audio features for a song
#
# When the user inputs a song, you are gonna want to retrieve the audio features of that song. How to do it?
#
# 1. Search the user input using the `sp.search()` function. This function works similarly to the "search" bar on the spotify app - using Spotify's intelligent search engine. That means that it can handle names of any songs or artists - even certain typos.
#
# 2. Find the uri of the song that the API gives you back.
#
# 3. Use `sp.audio_features` to retrieve the audio features of the song.

# %% [markdown]
# ### Lab: Create your collection of songs & audio features
#
# To move forward witht the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster.
#
# The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %% [markdown]
# Pasword security

# %%
import getpass

# %%
client_id=str(getpass.getpass('client_id?'))
client_secret=str(getpass.getpass('client_secret?'))
# Out:
# client_id?········
# client_secret?········

# %% [markdown]
# # Activity 3
#
# Iterate over the call (playlist) first 100 tracks to get all the songs ID, name, and artists.
#
# Output: Dictionary with key: song ID and values: list(song name, artist).

# %%
https://open.spotify.com/playlist/3g52zdlMRyYOqiFWGiFaGH?si=5517a25bdf1e4435
