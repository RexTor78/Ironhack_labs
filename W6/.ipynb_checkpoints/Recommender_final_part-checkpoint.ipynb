# %%
songs_df.head()
# Out:
#           Title  danceability  energy  key  loudness  mode  speechiness  \
# 0    Todo De Ti         0.780   0.719    3    -3.613     0       0.0506
# 1  Sexo Virtual         0.704   0.739    8    -3.286     1       0.1120
# 2         Nubes         0.735   0.755    0    -3.553     0       0.0513
# 3       Track 4         0.525   0.864    9   -21.716     1       0.7570
# 4     2/Catorce         0.768   0.560    3    -3.497     1       0.0859
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0         0.302          0.000196    0.0931    0.336  127.962
# 1         0.328          0.000019    0.0856    0.425  179.879
# 2         0.270          0.001870    0.1880    0.437   92.969
# 3         0.979          0.960000    0.8370    0.173   76.267
# 4         0.709          0.000791    0.1150    0.372  112.084

# %% [markdown]
# # Scaling

# %%
X = songs_df.drop(columns= ["Title"])

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
X_scaled = scaler.transform(X)

# %% [markdown]
# # Clustering

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=8,random_state=1234)

# %%
kmeans.fit(X_scaled)
# Out:
# KMeans(random_state=1234)

# %%
clusters = kmeans.predict(X_scaled)

# %%
clusters
# Out:
# array([4, 5, 4, 3, 1, 1, 6, 2, 5, 2, 4, 5, 0, 0, 7, 7, 5, 4, 5, 4, 7, 7,
#        4, 7, 0, 4, 4, 0, 7, 4, 0, 1, 5, 7, 7, 4, 7, 1, 5, 4, 4, 4, 4, 4,
#        1, 7, 0, 4, 5, 4, 3, 1, 1, 6, 2, 5, 2, 4, 5, 0, 0, 4, 4, 7, 2, 7,
#        0, 0, 4, 7, 0, 7, 4, 1, 6, 5, 7, 6, 0, 6, 4, 0, 2, 4, 7, 4, 7, 2,
#        0, 7, 4, 0, 0, 0, 4, 4, 6, 0, 7, 7, 0, 6, 4, 7, 4, 7, 4, 0, 6, 2,
#        2, 6, 6, 4, 4, 7, 5, 4, 2, 2, 4, 5, 4, 3, 1, 1, 6, 2, 5, 2, 4, 5,
#        0, 0, 4, 4, 5, 4, 3, 1, 1, 6, 2, 5, 2, 4, 5, 0, 0, 0, 7, 7, 4, 7,
#        6, 4, 6, 1, 1, 4, 6, 1, 6, 1, 1, 6, 4, 1, 4, 4, 2, 7, 4, 4, 4, 4,
#        5, 4, 4, 0, 5, 7, 7, 0, 1, 4, 7, 4, 7, 5, 4, 6, 7, 1, 6, 1, 5, 2,
#        1, 1, 7, 2, 4, 7, 4, 0, 0, 5, 0, 4, 0, 0, 7, 4, 5, 4, 5, 4, 7, 6,
#        4, 6, 1, 1, 4, 6, 1, 6, 1, 1, 6, 4, 1, 4, 4, 2, 4, 6, 2, 6, 5, 2,
#        4, 4, 0, 7, 5, 4, 4, 2, 2, 6, 0, 0, 0, 6, 0, 1, 1, 0, 4, 7, 0, 4,
#        5, 4], dtype=int32)

# %%
songs_df["Cluster"] = clusters

# %%
songs_df
# Out:
#                             Title  danceability  energy  key  loudness  mode  \
# 0                      Todo De Ti         0.780   0.719    3    -3.613     0
# 1                    Sexo Virtual         0.704   0.739    8    -3.286     1
# 2                           Nubes         0.735   0.755    0    -3.553     0
# 3                         Track 4         0.525   0.864    9   -21.716     1
# 4                       2/Catorce         0.768   0.560    3    -3.497     1
# ..                            ...           ...     ...  ...       ...   ...
# 261                  Vida de Rico         0.808   0.497    6    -4.008     1
# 262                          BEBÉ         0.862   0.720    4    -4.155     1
# 263                   5 pa las 12         0.645   0.639    4    -5.359     0
# 264            Travesuras - Remix         0.739   0.788    1    -5.198     1
# 265  Fragancia (with Jay Wheeler)         0.830   0.770    5    -3.364     0
#
# ...

# %%
sp.search("beatles")
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=beatles&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#        'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#        'id': '3WrFJ7ztbogyGnTHbHJFl2',
#        'name': 'The Beatles',
#        'type': 'artist',
#        'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
# ...

# %% [markdown]
# # Recommend

# %% [markdown]
# ##### Schema
# - search the user song in sp.search()
# - get the id of the song
# - get the audio features with the id
# - scale the audio features
# - find the cluster of the user song using the audio features
# - select a random song from the same cluster from your df
# - print the recommendation

# %% [markdown]
# ##### Code

# %%
def my_function():
    user = input("Tell me a song you like: ")
    user_result = sp.search(user, limit = 1)
    id_user = user_result["tracks"]["items"][0]["id"]
    user_features = pd.DataFrame(sp.audio_features(id_user)[0], index = [0])
    user_features = user_features.drop(columns = ["type","id","uri","track_href","analysis_url","duration_ms","time_signature"])

# %%
my_function()

# %%
user = input("Tell me a song you like: ")
# Out:
# Tell me a song you like: Yerterday

# %%
user_result = sp.search(user, limit = 1)

# %%
user_result["tracks"]["items"][0]["id"]
# Out:
# '3BQHpFgAp4l80e1XslIjNI'

# %%
id_user = user_result["tracks"]["items"][0]["id"]

# %%
pd.DataFrame(sp.audio_features(id_user))
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.332   0.179    5    -11.83     1       0.0326         0.879
#
#    instrumentalness  liveness  valence   tempo            type  \
# 0                 0    0.0886    0.315  96.529  audio_features
#
#                        id                                   uri  \
# 0  3BQHpFgAp4l80e1XslIjNI  spotify:track:3BQHpFgAp4l80e1XslIjNI
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3BQHpFgAp4l8...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3BQH...       125667
#
#    time_signature
# 0               4

# %%
user_features = pd.DataFrame(sp.audio_features(id_user)[0], index = [0])

# %%
user_features
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.332   0.179    5    -11.83     1       0.0326         0.879
#
#    instrumentalness  liveness  valence   tempo            type  \
# 0                 0    0.0886    0.315  96.529  audio_features
#
#                        id                                   uri  \
# 0  3BQHpFgAp4l80e1XslIjNI  spotify:track:3BQHpFgAp4l80e1XslIjNI
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3BQHpFgAp4l8...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3BQH...       125667
#
#    time_signature
# 0               4

# %%
user_features = user_features.drop(columns = ["type","id","uri","track_href","analysis_url","duration_ms","time_signature"])

# %%
user_features
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.332   0.179    5    -11.83     1       0.0326         0.879
#
#    instrumentalness  liveness  valence   tempo
# 0                 0    0.0886    0.315  96.529

# %%
user_scaled = scaler.transform(user_features)

# %%
user_scaled
# Out:
# array([[-3.48302393, -3.66523425, -0.09379214, -2.45294762,  0.95586038,
#         -0.74328076,  2.60740074, -0.14960055, -0.63560147, -1.2400089 ,
#         -0.82093522]])

# %%
cluster = kmeans.predict(user_scaled)

# %%
cluster
# Out:
# array([1], dtype=int32)

# %%
cluster = cluster[0]

# %%
cluster
# Out:
# 1

# %%
df_cluster = songs_df[songs_df["Cluster"] == cluster]

# %%
df_cluster
# Out:
#                    Title  danceability  energy  key  loudness  mode  \
# 4              2/Catorce         0.768   0.560    3    -3.497     1
# 5         Aquel Nap ZzZz         0.457   0.495    4    -6.044     1
# 31          Nada A Nadie         0.782   0.586    0    -6.482     1
# 37            La Llorera         0.472   0.485    7    -9.977     1
# 44                  Ella         0.823   0.717    2    -7.979     1
# 51             2/Catorce         0.768   0.560    3    -3.497     1
# 52        Aquel Nap ZzZz         0.457   0.495    4    -6.044     1
# 73        Volando Bajito         0.724   0.603    0    -8.348     1
# 124            2/Catorce         0.768   0.560    3    -3.497     1
# 125       Aquel Nap ZzZz         0.457   0.495    4    -6.044     1
# 139            2/Catorce         0.768   0.560    3    -3.497     1
# 140       Aquel Nap ZzZz         0.457   0.495    4    -6.044     1
# 157          Nunca Estoy         0.913   0.369    2    -5.299     1
# ...

# %%
recomendation = df_cluster.sample()

# %%
recomendation
# Out:
#            Title  danceability  energy  key  loudness  mode  speechiness  \
# 31  Nada A Nadie         0.782   0.586    0    -6.482     1       0.0659
#
#     acousticness  instrumentalness  liveness  valence  tempo  Cluster
# 31         0.114           0.00392     0.148    0.489  97.05        1

# %%
recomendation_name = recomendation["Title"].values[0]

# %%
recomendation_name
# Out:
# 'Nada A Nadie'

# %%
print("If you liked "+ user + ", you would also like: " + recomendation_name)
# Out:
# If you liked Yerterday, you would also like: Nada A Nadie
